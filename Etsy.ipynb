# %% [markdown]
# <a href="https://colab.research.google.com/github/Gitprincesskerry/IS362/blob/main/Etsy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<center> Etsy Recommender System </center>

# %% [markdown]
# ![etsy.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Task:
# 1. Perform a Scenario Design analysis as described below.  Consider whether it makes sense for your selected recommender system to perform scenario design twice, once for the organization (e.g. Amazon.com) and once for the organization's customers.
# 2. Attempt to reverse engineer what you can about the site, from the site interface and any available information that you can find on the Internet or elsewhere.
# 3. Include specific recommendations about how to improve the site's recommendation capabilities going forward.
# 4. Create your report using a Jupyter notebook, and create a discussion thread with a link to the GitHub repo where your Jupyter Notebook resides.  You are not expected to need to write code for this discussion assignment.

# %% [markdown]
# <b><center>The recommender website which will be analyzed today is Etsy.com.</b></center><br>The Etsy platform is for individuals seeking unique, custom or handmade items sold by creative entrepreneurs. In my opinion scenario design analysis should take place for both the organization and the customer. Let’s conduct a scenario design of the organization by answering the following 3 questions:
#
# 1. Who are your target users? The target users for individuals utilizing Etsy.com to shop are individuals seeking unique and/or custom made items. Also another target audience are current and prospective sellers.
#
#
# 2. What are their key goals? Some of the key goals of  of the customers is to obtain a custom/unique items for themselves or as a gift for someone else. Also there are other individuals who function as small businesses who purchase items for their business. Also sometimes customers get custom banners, pictures, t-shirts and etc. specialized for an event. From an organizational perspective Etsy makes money from sellers fees. To list an item this will cost one $0.20 cents. When an item is sold Etsy get’s 5% of the total transaction.
#
#
# 3. How can you help them accomplish their goals? To help Etsy accomplish their goals the recommender system can be upgraded. When analyzing the website other similar items aren’t recommended. Keywords are actually recommended. I like that fact that other keywords are recommended however having a definitive item which is similar to the current item on display will increase the likely hood of a customer finding the item they are seeking or even purchasing more than one item.

# %% [markdown]
# When doing a search on ETSY as depicted by the screenshot below. The search results are all pandora items which is excellent. It would be recommended to implement an algorithm on the backend which would show other related items such as other charm bracelets which are similar at the bottom of the page. The  algorithm should not include items the client has purchased already unless there is another section implemented named purchase again.

# %% [markdown]
# ![pandora screenshot.png](data:image/png;base64,...)
